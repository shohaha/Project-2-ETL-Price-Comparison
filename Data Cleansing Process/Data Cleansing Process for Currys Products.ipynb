# %% [markdown]
# # Setup
#
# - Load Dependancies
# - Import Datasets
# - Cleanse Whitespaces

# %%
import pandas as pd
import os

# %%
desktops = pd.read_csv('../Resources/Currys/Desktops_Prices.csv', skipinitialspace = True)
fridge_freezers = pd.read_csv('../Resources/Currys/Fridge Freezers_Prices.csv', skipinitialspace = True)
headphones = pd.read_csv('../Resources/Currys/Headphones_Prices.csv', skipinitialspace = True)
laptops = pd.read_csv('../Resources/Currys/Laptops_Prices.csv', skipinitialspace = True)
microwaves = pd.read_csv('../Resources/Currys/Microwaves_Prices.csv', skipinitialspace = True)
monitors = pd.read_csv('../Resources/Currys/Monitors_Prices.csv', skipinitialspace = True)
mobile_phones = pd.read_csv('../Resources/Currys/Phones_Prices.csv', skipinitialspace = True)
printers = pd.read_csv('../Resources/Currys/Printers_Prices.csv', skipinitialspace = True)
smart_watches = pd.read_csv('../Resources/Currys/Smart Watches_Prices.csv', skipinitialspace = True)
speakers = pd.read_csv('../Resources/Currys/Speakers_Prices.csv', skipinitialspace = True)
tablets = pd.read_csv('../Resources/Currys/Tablets_Prices.csv', skipinitialspace = True)
tumble_dryers = pd.read_csv('../Resources/Currys/Tumble Dryers_Prices.csv', skipinitialspace = True)
televisions = pd.read_csv('../Resources/Currys/TV_Prices.csv', skipinitialspace = True)
vac_cleaners = pd.read_csv('../Resources/Currys/Vacuum Cleaners_Prices.csv', skipinitialspace = True)
washer_dryers = pd.read_csv('../Resources/Currys/Washer Dryers_Prices.csv', skipinitialspace = True)
washing_machines = pd.read_csv('../Resources/Currys/Washing Machine_Prices.csv', skipinitialspace = True)

# %% [markdown]
# # Data Cleanse and Exploration Process

# %% [markdown]
# ## Desktops

# %%
# Print desktops csv as dataframe

desktops
# Out:
#     HP 22-df0040na 21.5" All-in-One PC - Intel® Pentium®, 128 GB SSD, White  \
# 0    HP 24-dp0002na 23.8" All-in-One PC - AMD Ryzen...
# 1    ASUS Zen AiO M5401 23.8" All-in-One PC - AMD R...
# 2    HP Pavilion TP01-2000na Desktop PC - AMD Ryzen...
# 3    LENOVO IdeaCentre AIO 3 27" All-in-One PC - AM...
# 4    LENOVO IdeaCentre AIO 3 23.8" All-in-One PC - ...
# ..                                                 ...
# 100  HP ENVY 34-c0000na 34" All-in-One PC - Intel® ...
# 101  ACER ConceptD CT300-51A Desktop PC - Intel® Co...
# 102  ASUS Chromebox 3 Mini Desktop PC - Intel® Cele...
# 103  DELL Inspiron AIO 7700 27" All-in-One PC - Int...
# 104  GIGABYTE BRIX Barebones Desktop PC - Intel® Co...
#
#        429.0   4.6   26.0
# 0     549.00  4.40  125.0
# 1     459.00  4.45   22.0
# 2     599.00  4.30  114.0
# 3     649.00   NaN    NaN
# 4     599.00   NaN    NaN
# ..       ...   ...    ...
# 100  2999.00   NaN    NaN
# 101  1799.00  5.00    3.0
# 102   249.99  4.20    8.0
# ...

# %%
# Insert columns titles for dataframe

desktops.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

desktops.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  HP 24-dp0002na 23.8" All-in-One PC - AMD Ryzen...      549.0
# 1  ASUS Zen AiO M5401 23.8" All-in-One PC - AMD R...      459.0
# 2  HP Pavilion TP01-2000na Desktop PC - AMD Ryzen...      599.0
# 3  LENOVO IdeaCentre AIO 3 27" All-in-One PC - AM...      649.0
# 4  LENOVO IdeaCentre AIO 3 23.8" All-in-One PC - ...      599.0
#
#    Customer Rating  Rating Count
# 0             4.40         125.0
# 1             4.45          22.0
# 2             4.30         114.0
# 3              NaN           NaN
# 4              NaN           NaN

# %%
# View dataframe types 

desktops.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

desktops['Rating Count'] = desktops['Rating Count'].fillna(0)

# %%
# Preview dataframe

desktops.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  HP 24-dp0002na 23.8" All-in-One PC - AMD Ryzen...      549.0
# 1  ASUS Zen AiO M5401 23.8" All-in-One PC - AMD R...      459.0
# 2  HP Pavilion TP01-2000na Desktop PC - AMD Ryzen...      599.0
# 3  LENOVO IdeaCentre AIO 3 27" All-in-One PC - AM...      649.0
# 4  LENOVO IdeaCentre AIO 3 23.8" All-in-One PC - ...      599.0
#
#    Customer Rating  Rating Count
# 0             4.40         125.0
# 1             4.45          22.0
# 2             4.30         114.0
# 3              NaN           0.0
# 4              NaN           0.0

# %%
# Save cleansed data to new CSV

#desktops.to_csv('../Clean_Datasets/Currys_Desktops.csv', index=False)

# %% [markdown]
# ## Fridge Freezers

# %%
# Print fridge_freezers csv as dataframe

fridge_freezers
# Out:
#     SAMSUNG RS8000 RS67A8810S9/EU American-Style Fridge Freezer - Matte Stainless  \
# 0    BOSCH Serie 2 KGN34NWEAG 50/50 Fridge Freezer ...
# 1    BOSCH Serie 4 KGN39VLEBG 70/30 Fridge Freezer ...
# 2         BOSCH KGN27NLFAG 50/50 Fridge Freezer - Inox
# 3    LG GSLD50DSXM American-Style Fridge Freezer - ...
# 4     ESSENTIALS C50BS20 60/40 Fridge Freezer - Silver
# ..                                                 ...
# 456   LIEBHERR CNsfd5724 50/50 Fridge Freezer - Silver
# 457      LIEBHERR CNd5023 50/50 Fridge Freezer - White
# 458     LIEBHERR CNd 5204 50/50 Fridge Freezer - White
# 459  NEFF KI5872FE0G Integrated 70/30 Fridge Freeze...
# 460        SMEG FAB32LRD5UK 60/40 Fridge Freezer - Red
#
#      1379.99  4.45  1803.0
# 0     438.00  4.55   543.0
# 1     699.99  4.60   135.0
# 2     429.99  4.40    64.0
# 3     899.99  4.60    33.0
# 4     199.99  4.05   582.0
# ..       ...   ...     ...
# 456  1089.99   NaN     NaN
# 457   829.00   NaN     NaN
# ...

# %%
# Insert columns titles for dataframe

fridge_freezers.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

fridge_freezers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSCH Serie 2 KGN34NWEAG 50/50 Fridge Freezer ...     438.00
# 1  BOSCH Serie 4 KGN39VLEBG 70/30 Fridge Freezer ...     699.99
# 2       BOSCH KGN27NLFAG 50/50 Fridge Freezer - Inox     429.99
# 3  LG GSLD50DSXM American-Style Fridge Freezer - ...     899.99
# 4   ESSENTIALS C50BS20 60/40 Fridge Freezer - Silver     199.99
#
#    Customer Rating  Rating Count
# 0             4.55         543.0
# 1             4.60         135.0
# 2             4.40          64.0
# 3             4.60          33.0
# 4             4.05         582.0

# %%
# View dataframe types 

fridge_freezers.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

fridge_freezers['Rating Count'] = fridge_freezers['Rating Count'].fillna(0)

# %%
# Print dataframe

fridge_freezers
# Out:
#                                           Product Name  Price (£)  \
# 0    BOSCH Serie 2 KGN34NWEAG 50/50 Fridge Freezer ...     438.00
# 1    BOSCH Serie 4 KGN39VLEBG 70/30 Fridge Freezer ...     699.99
# 2         BOSCH KGN27NLFAG 50/50 Fridge Freezer - Inox     429.99
# 3    LG GSLD50DSXM American-Style Fridge Freezer - ...     899.99
# 4     ESSENTIALS C50BS20 60/40 Fridge Freezer - Silver     199.99
# ..                                                 ...        ...
# 456   LIEBHERR CNsfd5724 50/50 Fridge Freezer - Silver    1089.99
# 457      LIEBHERR CNd5023 50/50 Fridge Freezer - White     829.00
# 458     LIEBHERR CNd 5204 50/50 Fridge Freezer - White     569.99
# 459  NEFF KI5872FE0G Integrated 70/30 Fridge Freeze...     779.00
# 460        SMEG FAB32LRD5UK 60/40 Fridge Freezer - Red    2099.99
#
#      Customer Rating  Rating Count
# 0               4.55         543.0
# 1               4.60         135.0
# 2               4.40          64.0
# ...

# %%
# Save cleansed data to new CSV

#fridge_freezers.to_csv('../Clean_Datasets/Currys_Fridge_Freezer.csv', index=False)

# %% [markdown]
# ## Headphones

# %%
# Print headphones csv as dataframe

headphones
# Out:
#     SONY WF-1000XM4 Wireless Bluetooth Noise-Cancelling Earbuds - Black  \
# 0    BOSE QuietComfort Wireless Bluetooth Noise-Can...
# 1    JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...
# 2    BOSE QuietComfort Wireless Bluetooth Noise-Can...
# 3    SONY WF-1000XM4 Wireless Bluetooth Noise-Cance...
# 4    JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...
# ..                                                 ...
# 911              URBANISTA Barcelona Earphones - Black
# 912  GROOV-E GV-EMJ15 EarMOJI's Cool Face Kids Head...
# 913  FRESH N REBEL Caps 2 Wireless Bluetooth Headph...
# 914  VOLKANO Alloy VK-1007-PR Earphones - Purple & ...
# 915    SONY WF-XB700 Wireless Bluetooth Earbuds - Blue
#
#       219.0  4.35  466.0
# 0    199.00  4.35  261.0
# 1     99.99  4.35  136.0
# 2    199.00  4.35  261.0
# 3    219.00  4.35  466.0
# 4     99.99  4.35  136.0
# ..      ...   ...    ...
# 911   22.99   NaN    NaN
# 912   13.99  5.00    1.0
# 913   49.99   NaN    NaN
# ...

# %%
# Insert columns titles for dataframe

headphones.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

headphones.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSE QuietComfort Wireless Bluetooth Noise-Can...     199.00
# 1  JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...      99.99
# 2  BOSE QuietComfort Wireless Bluetooth Noise-Can...     199.00
# 3  SONY WF-1000XM4 Wireless Bluetooth Noise-Cance...     219.00
# 4  JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...      99.99
#
#    Customer Rating  Rating Count
# 0             4.35         261.0
# 1             4.35         136.0
# 2             4.35         261.0
# 3             4.35         466.0
# 4             4.35         136.0

# %%
# View dataframe types 

headphones.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

headphones['Rating Count'] = headphones['Rating Count'].fillna(0)

# %%
# Print dataframe

headphones
# Out:
#                                           Product Name  Price (£)  \
# 0    BOSE QuietComfort Wireless Bluetooth Noise-Can...     199.00
# 1    JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...      99.99
# 2    BOSE QuietComfort Wireless Bluetooth Noise-Can...     199.00
# 3    SONY WF-1000XM4 Wireless Bluetooth Noise-Cance...     219.00
# 4    JBL Live Pro+ TWS Wireless Bluetooth Noise-Can...      99.99
# ..                                                 ...        ...
# 911              URBANISTA Barcelona Earphones - Black      22.99
# 912  GROOV-E GV-EMJ15 EarMOJI's Cool Face Kids Head...      13.99
# 913  FRESH N REBEL Caps 2 Wireless Bluetooth Headph...      49.99
# 914  VOLKANO Alloy VK-1007-PR Earphones - Purple & ...       8.99
# 915    SONY WF-XB700 Wireless Bluetooth Earbuds - Blue      39.97
#
#      Customer Rating  Rating Count
# 0               4.35         261.0
# 1               4.35         136.0
# 2               4.35         261.0
# ...

# %%
# Save cleansed data to new CSV

#headphones.to_csv('../Clean_Datasets/Currys_Headphones.csv', index=False)

# %% [markdown]
# ## Laptops

# %%
# Print laptops csv as dataframe

laptops
# Out:
#     ASUS Zenbook Flip UX363EA 13.3" 2 in 1 Laptop - Intel® Core™ i5, 512 GB SSD, Grey  \
# 0    HP Pavilion 14-ec0537sa 14" Laptop - AMD Ryzen...
# 1    ACER Aspire 5 A514-54 14" Laptop & Microsoft 3...
# 2    MICROSOFT 13.5" Surface Laptop 4 - AMD Ryzen 5...
# 3    ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...
# 4    ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...
# ..                                                 ...
# 364  VENTURER Europa Plus 14" Laptop - Intel® Celer...
# 365  ACER ConceptD 3 14" Laptop - Intel® Core™ i7, ...
# 366  VENTURER Europa 11 LT 11.6" Laptop - Intel® Ce...
# 367  MICROSOFT 13.5" Surface Laptop 3 - Intel® Core...
# 368  DYNABOOK Toshiba Portégé X30W-J-130 13.3" 2 in...
#
#        699.0  4.45   27.0
# 0     399.00   NaN    NaN
# 1     449.00   NaN    NaN
# 2     999.00  4.60   28.0
# 3     599.00  4.35  139.0
# 4     549.00  4.35  139.0
# ..       ...   ...    ...
# 364   229.00  4.20    7.0
# 365  1499.99  4.00    2.0
# 366   189.00  3.50   61.0
# ...

# %%
# Insert columns titles for dataframe

laptops.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

laptops.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  HP Pavilion 14-ec0537sa 14" Laptop - AMD Ryzen...      399.0
# 1  ACER Aspire 5 A514-54 14" Laptop & Microsoft 3...      449.0
# 2  MICROSOFT 13.5" Surface Laptop 4 - AMD Ryzen 5...      999.0
# 3  ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...      599.0
# 4  ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...      549.0
#
#    Customer Rating  Rating Count
# 0              NaN           NaN
# 1              NaN           NaN
# 2             4.60          28.0
# 3             4.35         139.0
# 4             4.35         139.0

# %%
# View dataframe types 

laptops.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

laptops['Rating Count'] = laptops['Rating Count'].fillna(0)

# %%
# Print dataframe

laptops
# Out:
#                                           Product Name  Price (£)  \
# 0    HP Pavilion 14-ec0537sa 14" Laptop - AMD Ryzen...     399.00
# 1    ACER Aspire 5 A514-54 14" Laptop & Microsoft 3...     449.00
# 2    MICROSOFT 13.5" Surface Laptop 4 - AMD Ryzen 5...     999.00
# 3    ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...     599.00
# 4    ACER Swift 3 14" Laptop - AMD Ryzen 5, 1 TB SS...     549.00
# ..                                                 ...        ...
# 364  VENTURER Europa Plus 14" Laptop - Intel® Celer...     229.00
# 365  ACER ConceptD 3 14" Laptop - Intel® Core™ i7, ...    1499.99
# 366  VENTURER Europa 11 LT 11.6" Laptop - Intel® Ce...     189.00
# 367  MICROSOFT 13.5" Surface Laptop 3 - Intel® Core...    1987.00
# 368  DYNABOOK Toshiba Portégé X30W-J-130 13.3" 2 in...    1199.00
#
#      Customer Rating  Rating Count
# 0                NaN           0.0
# 1                NaN           0.0
# 2               4.60          28.0
# ...

# %%
# Save cleansed data to new CSV

#laptops.to_csv('../Clean_Datasets/Currys_Laptops.csv', index=False)

# %% [markdown]
# ## Microwaves

# %%
# Print microwaves csv as dataframe

microwaves
# Out:
#          SAMSUNG MS23F301TFK/EU Solo Microwave - Black   109.0  4.45    33.0
# 0    SAMSUNG MC28M6055CK/EU Combination Microwave -...  199.00  4.20   100.0
# 1       SAMSUNG MS23K3515AS/EU Solo Microwave - Silver   99.99  4.30   668.0
# 2               KENWOOD K25MB21 Solo Microwave - Black   99.99  4.60   124.0
# 3    PANASONIC NN-CT56JBBPQ Combination Microwave -...  249.00  4.50  1760.0
# 4    PANASONIC NN-CT55JWBPQ Combination Microwave -...  249.00  4.50  1962.0
# ..                                                 ...     ...   ...     ...
# 177              DAEWOO SDA2086GE Solo Microwave - Red   89.99  4.85     3.0
# 178           DAEWOO SDA2089GE Solo Microwave - Silver   99.99   NaN     NaN
# 179       SWAN Retro SM22030LGRN Solo Microwave - Grey   99.99   NaN     NaN
# 180     SWAN Nordic SM22036LBLUN Solo Microwave - Blue  119.99   NaN     NaN
# 181             TOWER T24034BLK Solo Microwave - Black   74.99   NaN     NaN
#
# [182 rows x 4 columns]

# %%
# Insert columns titles for dataframe

microwaves.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

microwaves.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG MC28M6055CK/EU Combination Microwave -...     199.00
# 1     SAMSUNG MS23K3515AS/EU Solo Microwave - Silver      99.99
# 2             KENWOOD K25MB21 Solo Microwave - Black      99.99
# 3  PANASONIC NN-CT56JBBPQ Combination Microwave -...     249.00
# 4  PANASONIC NN-CT55JWBPQ Combination Microwave -...     249.00
#
#    Customer Rating  Rating Count
# 0              4.2         100.0
# 1              4.3         668.0
# 2              4.6         124.0
# 3              4.5        1760.0
# 4              4.5        1962.0

# %%
# View dataframe types 

microwaves.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

microwaves['Rating Count'] = microwaves['Rating Count'].fillna(0)

# %%
# Print dataframe

microwaves
# Out:
#                                           Product Name  Price (£)  \
# 0    SAMSUNG MC28M6055CK/EU Combination Microwave -...     199.00
# 1       SAMSUNG MS23K3515AS/EU Solo Microwave - Silver      99.99
# 2               KENWOOD K25MB21 Solo Microwave - Black      99.99
# 3    PANASONIC NN-CT56JBBPQ Combination Microwave -...     249.00
# 4    PANASONIC NN-CT55JWBPQ Combination Microwave -...     249.00
# ..                                                 ...        ...
# 177              DAEWOO SDA2086GE Solo Microwave - Red      89.99
# 178           DAEWOO SDA2089GE Solo Microwave - Silver      99.99
# 179       SWAN Retro SM22030LGRN Solo Microwave - Grey      99.99
# 180     SWAN Nordic SM22036LBLUN Solo Microwave - Blue     119.99
# 181             TOWER T24034BLK Solo Microwave - Black      74.99
#
#      Customer Rating  Rating Count
# 0               4.20         100.0
# 1               4.30         668.0
# 2               4.60         124.0
# ...

# %%
# Save cleansed data to new CSV

#microwaves.to_csv('../Clean_Datasets/Currys_Microwaves.csv', index=False)

# %% [markdown]
# ## Monitors

# %%
# Print monitors csv as dataframe

monitors
# Out:
#     LENOVO C24-25 Full HD 23.8" VA LCD Monitor - Black   109.0  4.55   236.0
# 0    ACER SA220QAbi Full HD 21.5" IPS LCD Monitor -...   99.00   NaN     NaN
# 1       SAMSUNG C24F396 Full HD 24" Curved LED Monitor  149.00  4.55  1728.0
# 2    ACER KA222Qbi Full HD 21.5" IPS LED Monitor - ...   99.00  4.40    10.0
# 3    ACER ED270RPbiipx Full HD 27” Curved LED Monit...  199.00  4.40    89.0
# 4    LENOVO L15 Full HD 15.6" IPS LCD Mobile Monito...  149.00   NaN     NaN
# ..                                                 ...     ...   ...     ...
# 153  IIYAMA ProLite XUB2294HSU-B1 22' Full HD LCD M...  139.00  4.55    21.0
# 154            HANWHA SMT-1935 19" LCD Monitor - Black  249.99  2.25     2.0
# 155  IIYAMA ProLite X2483HSU-B3 Full HD 24” LCD Mon...  155.00  4.25    20.0
# 156  HANWHA WiseNet SMT-4033 Full HD 39.5" LCD Moni...  899.99   NaN     NaN
# 157  IIYAMA ProLite XU2493HS-B4 23.8" Full HD IPS L...  165.00   NaN     NaN
#
# [158 rows x 4 columns]

# %%
# Insert columns titles for dataframe

monitors.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

monitors.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  ACER SA220QAbi Full HD 21.5" IPS LCD Monitor -...       99.0
# 1     SAMSUNG C24F396 Full HD 24" Curved LED Monitor      149.0
# 2  ACER KA222Qbi Full HD 21.5" IPS LED Monitor - ...       99.0
# 3  ACER ED270RPbiipx Full HD 27” Curved LED Monit...      199.0
# 4  LENOVO L15 Full HD 15.6" IPS LCD Mobile Monito...      149.0
#
#    Customer Rating  Rating Count
# 0              NaN           NaN
# 1             4.55        1728.0
# 2             4.40          10.0
# 3             4.40          89.0
# 4              NaN           NaN

# %%
# View dataframe types 

monitors.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

monitors['Rating Count'] = monitors['Rating Count'].fillna(0)

# %%
# Print dataframe

monitors.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  ACER SA220QAbi Full HD 21.5" IPS LCD Monitor -...       99.0
# 1     SAMSUNG C24F396 Full HD 24" Curved LED Monitor      149.0
# 2  ACER KA222Qbi Full HD 21.5" IPS LED Monitor - ...       99.0
# 3  ACER ED270RPbiipx Full HD 27” Curved LED Monit...      199.0
# 4  LENOVO L15 Full HD 15.6" IPS LCD Mobile Monito...      149.0
#
#    Customer Rating  Rating Count
# 0              NaN           0.0
# 1             4.55        1728.0
# 2             4.40          10.0
# 3             4.40          89.0
# 4              NaN           0.0

# %%
# Save cleansed data to new CSV

#monitors.to_csv('../Clean_Datasets/Currys_Monitors.csv', index=False)

# %% [markdown]
# ## Mobile Phones

# %%
# Print mobile_phones csv as dataframe

mobile_phones
# Out:
#     SAMSUNG Galaxy A52s 5G - 128 GB, Awesome White   299.0  Unnamed: 2  \
# 0                  APPLE iPhone 13 - 128 GB, Green  729.00         NaN
# 1           MOTOROLA Edge 30 - 128 GB, Meteor Grey  379.99         NaN
# 2      SAMSUNG Galaxy S21 FE 5G - 128 GB, Graphite  599.00        3.60
# 3                 HONOR Magic4 Pro - 256 GB, Black  949.99         NaN
# 4                   APPLE iPhone 13 - 128 GB, Blue  729.00        4.60
# ..                                             ...     ...         ...
# 351                APPLE iPhone SE - 128 GB, White  409.97        4.50
# 352                MOTOROLA Moto G10 - 64 GB, Grey  129.99        4.25
# 353     APPLE iPhone 12 Pro Max - 128 GB, Graphite  797.97        4.65
# 354         MOTOROLA Moto G30 - 128 GB, Pastel Sky  139.99        4.35
# 355                APPLE iPhone 11 - 256 GB, Green  639.00        4.60
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           6.0
# 3           NaN
# 4          82.0
# ...

# %%
# Insert columns titles for dataframe

mobile_phones.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

mobile_phones.head()
# Out:
#                                   Product Name  Price (£)  Customer Rating  \
# 0              APPLE iPhone 13 - 128 GB, Green     729.00              NaN
# 1       MOTOROLA Edge 30 - 128 GB, Meteor Grey     379.99              NaN
# 2  SAMSUNG Galaxy S21 FE 5G - 128 GB, Graphite     599.00              3.6
# 3             HONOR Magic4 Pro - 256 GB, Black     949.99              NaN
# 4               APPLE iPhone 13 - 128 GB, Blue     729.00              4.6
#
#    Rating Count
# 0           NaN
# 1           NaN
# 2           6.0
# 3           NaN
# 4          82.0

# %%
# View dataframe types 

mobile_phones.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

mobile_phones['Rating Count'] = mobile_phones['Rating Count'].fillna(0)

# %%
# Print dataframe

mobile_phones.head()
# Out:
#                                   Product Name  Price (£)  Customer Rating  \
# 0              APPLE iPhone 13 - 128 GB, Green     729.00              NaN
# 1       MOTOROLA Edge 30 - 128 GB, Meteor Grey     379.99              NaN
# 2  SAMSUNG Galaxy S21 FE 5G - 128 GB, Graphite     599.00              3.6
# 3             HONOR Magic4 Pro - 256 GB, Black     949.99              NaN
# 4               APPLE iPhone 13 - 128 GB, Blue     729.00              4.6
#
#    Rating Count
# 0           0.0
# 1           0.0
# 2           6.0
# 3           0.0
# 4          82.0

# %%
# Save cleansed data to new CSV

#mobile_phones.to_csv('../Clean_Datasets/Currys_Mobile_Phones.csv', index=False)

# %% [markdown]
# ## Printers

# %%
# Print printers csv as dataframe

printers
# Out:
#     EPSON Expression Home XP-3155 All-in-One Wireless Inkjet Printer   59.99  \
# 0    HP DeskJet 2721e All-in-One Wireless Inkjet Pr...                 59.99
# 1    HP ENVY 6032e All-in-One Wireless Inkjet Print...                 89.99
# 2    HP ENVY Inspire 7924e All-in-One Wireless Inkj...                149.99
# 3    HP LaserJet M209dwe Monochrome Wireless Laser ...                199.99
# 4    CANON PIXMA TS3355 All-in-One Wireless Inkjet ...                 44.99
# ..                                                 ...                   ...
# 143  XEROX B235 Monochrome All-in-One Wireless Lase...                249.00
# 144          EPSON EcoTank ET-14000 A3+ Inkjet Printer                539.00
# 145  CANON PIXMA TR150 All-in-One Wireless Inkjet P...                229.99
# 146             DREMEL Idea Builder 3D40-01 3D Printer                999.00
# 147     CANON SELPHY Square QX10 Photo Printer - Green                149.00
#
#       4.2   172.0
# 0    4.15   450.0
# ...

# %%
# Insert columns titles for dataframe

printers.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

printers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  HP DeskJet 2721e All-in-One Wireless Inkjet Pr...      59.99
# 1  HP ENVY 6032e All-in-One Wireless Inkjet Print...      89.99
# 2  HP ENVY Inspire 7924e All-in-One Wireless Inkj...     149.99
# 3  HP LaserJet M209dwe Monochrome Wireless Laser ...     199.99
# 4  CANON PIXMA TS3355 All-in-One Wireless Inkjet ...      44.99
#
#    Customer Rating  Rating Count
# 0             4.15         450.0
# 1             4.15         445.0
# 2              NaN           NaN
# 3             3.50           5.0
# 4             4.05        2340.0

# %%
# View dataframe types 

printers.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

printers['Rating Count'] = printers['Rating Count'].fillna(0)

# %%
# Print dataframe

printers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  HP DeskJet 2721e All-in-One Wireless Inkjet Pr...      59.99
# 1  HP ENVY 6032e All-in-One Wireless Inkjet Print...      89.99
# 2  HP ENVY Inspire 7924e All-in-One Wireless Inkj...     149.99
# 3  HP LaserJet M209dwe Monochrome Wireless Laser ...     199.99
# 4  CANON PIXMA TS3355 All-in-One Wireless Inkjet ...      44.99
#
#    Customer Rating  Rating Count
# 0             4.15         450.0
# 1             4.15         445.0
# 2              NaN           0.0
# 3             3.50           5.0
# 4             4.05        2340.0

# %%
# Save cleansed data to new CSV

#printers.to_csv('../Clean_Datasets/Currys_Printers.csv', index=False)

# %% [markdown]
# ## Smart Watches

# %%
# Print smart_watches csv as dataframe

smart_watches
# Out:
#     APPLE Watch Series 7 - Midnight Aluminium with Midnight Sports Band, 41 mm  \
# 0                   FITBIT Versa 3 - Soft Gold & Olive
# 1                               FITBIT Versa 3 - Black
# 2    SAMSUNG Galaxy Watch4 Classic BT - Stainless S...
# 3              HUAWEI Watch GT 3 Active - Black, 46 mm
# 4    SAMSUNG Galaxy Watch4 Classic BT - Stainless S...
# ..                                                 ...
# 368                CPR GUARDIAN II Smart Watch - Black
# 369                   MOBVOI TicWatch Pro 2020 - Black
# 370  HUAWEI Watch GT 3 Pro Ceramic - Gold & White, ...
# 371       POLAR Unite Fitness Watch - Red, Small/Large
# 372                   CPR GUARDN II Smart Watch - Grey
#
#      369.0   4.6  115.0
# 0    159.0  4.30  130.0
# 1    159.0  4.20  477.0
# 2    349.0  3.90   20.0
# 3    169.0  4.50   14.0
# 4    369.0  4.60   41.0
# ..     ...   ...    ...
# 368  199.0   NaN    NaN
# 369  229.0  4.35    3.0
# 370  499.0   NaN    NaN
# 371  134.5   NaN    NaN
# ...

# %%
# Insert columns titles for dataframe

smart_watches.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

smart_watches.head()
# Out:
#                                         Product Name  Price (£)  \
# 0                 FITBIT Versa 3 - Soft Gold & Olive      159.0
# 1                             FITBIT Versa 3 - Black      159.0
# 2  SAMSUNG Galaxy Watch4 Classic BT - Stainless S...      349.0
# 3            HUAWEI Watch GT 3 Active - Black, 46 mm      169.0
# 4  SAMSUNG Galaxy Watch4 Classic BT - Stainless S...      369.0
#
#    Customer Rating  Rating Count
# 0              4.3         130.0
# 1              4.2         477.0
# 2              3.9          20.0
# 3              4.5          14.0
# 4              4.6          41.0

# %%
# View dataframe types 

smart_watches.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

smart_watches['Rating Count'] = smart_watches['Rating Count'].fillna(0)

# %%
# Print dataframe

smart_watches.head()
# Out:
#                                         Product Name  Price (£)  \
# 0                 FITBIT Versa 3 - Soft Gold & Olive      159.0
# 1                             FITBIT Versa 3 - Black      159.0
# 2  SAMSUNG Galaxy Watch4 Classic BT - Stainless S...      349.0
# 3            HUAWEI Watch GT 3 Active - Black, 46 mm      169.0
# 4  SAMSUNG Galaxy Watch4 Classic BT - Stainless S...      369.0
#
#    Customer Rating  Rating Count
# 0              4.3         130.0
# 1              4.2         477.0
# 2              3.9          20.0
# 3              4.5          14.0
# 4              4.6          41.0

# %%
# Save cleansed data to new CSV

#smart_watches.to_csv('../Clean_Datasets/Currys_Smart_Watches.csv', index=False)

# %% [markdown]
# ## Speakers

# %%
# Print speakers csv as dataframe

speakers
# Out:
#       SONY SRS-XB43 Portable Bluetooth Speaker - Black   149.0  4.65  172.0
# 0      JBL Charge 5 Portable Bluetooth Speaker - Black  169.00  4.70  268.0
# 1    ULTIMATE EARS BOOM 3 Portable Bluetooth Speake...  129.00  4.60  206.0
# 2      SONY SRS-XB43 Portable Bluetooth Speaker - Blue  149.00  4.55   60.0
# 3    JBL Xtreme 2 Portable Bluetooth Speaker - Gun ...  149.00  4.70   98.0
# 4    JBL Flip Essential Portable Bluetooth Speaker ...   79.99  4.65  676.0
# ..                                                 ...     ...   ...    ...
# 514  FRESH N REBEL Rockbox Bold XS Portable Bluetoo...   38.99  4.00    1.0
# 515  FLEXSON FLXS1FS2011EU SONOS One Floorstand Fix...   89.00  4.65    3.0
# 516  FLEXSON S1-SPC Sonos Speaker Power Adapter - B...    9.99   NaN    NaN
# 517  AUDIO PRO D-1 Wireless Multi-room Speaker - Black  350.00   NaN    NaN
# 518  FLEXSON FLXSMWM1022 Sonos Move Wall Mount Fixe...   19.99   NaN    NaN
#
# [519 rows x 4 columns]

# %%
# Insert columns titles for dataframe

speakers.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

speakers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0    JBL Charge 5 Portable Bluetooth Speaker - Black     169.00
# 1  ULTIMATE EARS BOOM 3 Portable Bluetooth Speake...     129.00
# 2    SONY SRS-XB43 Portable Bluetooth Speaker - Blue     149.00
# 3  JBL Xtreme 2 Portable Bluetooth Speaker - Gun ...     149.00
# 4  JBL Flip Essential Portable Bluetooth Speaker ...      79.99
#
#    Customer Rating  Rating Count
# 0             4.70         268.0
# 1             4.60         206.0
# 2             4.55          60.0
# 3             4.70          98.0
# 4             4.65         676.0

# %%
# View dataframe types 

speakers.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

speakers['Rating Count'] = speakers['Rating Count'].fillna(0)

# %%
# Print dataframe

speakers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0    JBL Charge 5 Portable Bluetooth Speaker - Black     169.00
# 1  ULTIMATE EARS BOOM 3 Portable Bluetooth Speake...     129.00
# 2    SONY SRS-XB43 Portable Bluetooth Speaker - Blue     149.00
# 3  JBL Xtreme 2 Portable Bluetooth Speaker - Gun ...     149.00
# 4  JBL Flip Essential Portable Bluetooth Speaker ...      79.99
#
#    Customer Rating  Rating Count
# 0             4.70         268.0
# 1             4.60         206.0
# 2             4.55          60.0
# 3             4.70          98.0
# 4             4.65         676.0

# %%
# Save cleansed data to new CSV

#speakers.to_csv('../Clean_Datasets/Currys_Speakers.csv', index=False)

# %% [markdown]
# ## Tablets

# %%
# Print tablets csv as dataframe

tablets
# Out:
#     SAMSUNG Galaxy Tab A8 10.5" Tablet (64 GB, Graphite) & Book Cover (Dark Grey) Bundle  \
# 0    SAMSUNG Galaxy Tab A8 10.5" Tablet (64 GB, Pin...
# 1    SAMSUNG Galaxy Tab A8 10.5" Tablet (32 GB, Sil...
# 2    SAMSUNG Galaxy Tab A7 Lite 8.7" Tablet - 32 GB...
# 3    SAMSUNG Galaxy Tab S6 Lite 10.4” Tablet (UK & ...
# 4    SAMSUNG Galaxy Tab S8 11" Tablet - 256 GB, Gra...
# ..                                                 ...
# 214  SAMSUNG Galaxy Tab S6 Lite 10.4” Tablet - 128 ...
# 215  LENOVO Tab M7 7" Tablet with Kids Bumper Case ...
# 216  APPLE 10.9" iPad Air Cellular (2020) - 256 GB,...
# 217  APPLE 7.9" iPad mini 5 Cellular (2019) - 256 G...
# 218  SAMSUNG Galaxy Tab S6 Lite 10.4" Tablet - 64 G...
#
#       288.0  Unnamed: 2  Unnamed: 3
# 0    288.00         NaN         NaN
# 1    258.00         NaN         NaN
# 2    119.00        4.60        95.0
# 3    269.00        4.50       526.0
# 4    599.00         NaN         NaN
# ..      ...         ...         ...
# ...

# %%
# Insert columns titles for dataframe

tablets.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

tablets.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Galaxy Tab A8 10.5" Tablet (64 GB, Pin...      288.0
# 1  SAMSUNG Galaxy Tab A8 10.5" Tablet (32 GB, Sil...      258.0
# 2  SAMSUNG Galaxy Tab A7 Lite 8.7" Tablet - 32 GB...      119.0
# 3  SAMSUNG Galaxy Tab S6 Lite 10.4” Tablet (UK & ...      269.0
# 4  SAMSUNG Galaxy Tab S8 11" Tablet - 256 GB, Gra...      599.0
#
#    Customer Rating  Rating Count
# 0              NaN           NaN
# 1              NaN           NaN
# 2              4.6          95.0
# 3              4.5         526.0
# 4              NaN           NaN

# %%
# View dataframe types 

tablets.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

tablets['Rating Count'] = tablets['Rating Count'].fillna(0)

# %%
# Print dataframe

tablets.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Galaxy Tab A8 10.5" Tablet (64 GB, Pin...      288.0
# 1  SAMSUNG Galaxy Tab A8 10.5" Tablet (32 GB, Sil...      258.0
# 2  SAMSUNG Galaxy Tab A7 Lite 8.7" Tablet - 32 GB...      119.0
# 3  SAMSUNG Galaxy Tab S6 Lite 10.4” Tablet (UK & ...      269.0
# 4  SAMSUNG Galaxy Tab S8 11" Tablet - 256 GB, Gra...      599.0
#
#    Customer Rating  Rating Count
# 0              NaN           0.0
# 1              NaN           0.0
# 2              4.6          95.0
# 3              4.5         526.0
# 4              NaN           0.0

# %%
# Save cleansed data to new CSV

#tablets.to_csv('../Clean_Datasets/Currys_Tablets.csv', index=False)

# %% [markdown]
# ## Tumble Dryers

# %%
# Print tumble_dryers csv as dataframe

tumble_dryers
# Out:
#     SAMSUNG Series 5+ DV90T5240AN/S1 WiFi-enabled 9 kg Heat Pump Tumble Dryer - Graphite  \
# 0    BOSCH Serie 4 WTN85280GB Condenser Tumble Drye...
# 1    BOSCH Serie 4 WTH84000GB 8 kg Heat Pump Tumble...
# 2    SAMSUNG DV9BTA020AE 9 kg Heat Pump Tumble Drye...
# 3    LOGIK LCD7W18 7 kg Condenser Tumble Dryer - White
# 4       LOGIK LVD7W18 7 kg Vented Tumble Dryer - White
# ..                                                 ...
# 127  BOSCH Serie 8 WTX88EH9GB Smart 9 kg Heat Pump ...
# 128  AEG ProSense T6DBG822N Condenser Tumble Dryer ...
# 129  HISENSE Essential DHGE901B 9 kg Heat Pump Tumb...
# 130  INDESIT I3 D81B UK 8 kg Condenser Tumble Dryer...
# 131  HISENSE DCGE802B 8 kg Condenser Tumble Dryer -...
#
#      769.99   4.5   163.0
# 0    429.99  4.25   718.0
# 1    469.99  4.15   119.0
# 2    599.99  4.75    11.0
# 3    189.00  4.60  2337.0
# 4    189.00  4.35  3319.0
# ..      ...   ...     ...
# 127  949.99  4.10    21.0
# 128  579.99  4.30   236.0
# ...

# %%
# Insert columns titles for dataframe

tumble_dryers.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

tumble_dryers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSCH Serie 4 WTN85280GB Condenser Tumble Drye...     429.99
# 1  BOSCH Serie 4 WTH84000GB 8 kg Heat Pump Tumble...     469.99
# 2  SAMSUNG DV9BTA020AE 9 kg Heat Pump Tumble Drye...     599.99
# 3  LOGIK LCD7W18 7 kg Condenser Tumble Dryer - White     189.00
# 4     LOGIK LVD7W18 7 kg Vented Tumble Dryer - White     189.00
#
#    Customer Rating  Rating Count
# 0             4.25         718.0
# 1             4.15         119.0
# 2             4.75          11.0
# 3             4.60        2337.0
# 4             4.35        3319.0

# %%
# View dataframe types 

tumble_dryers.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

tumble_dryers['Rating Count'] = tumble_dryers['Rating Count'].fillna(0)

# %%
# Print dataframe

tumble_dryers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSCH Serie 4 WTN85280GB Condenser Tumble Drye...     429.99
# 1  BOSCH Serie 4 WTH84000GB 8 kg Heat Pump Tumble...     469.99
# 2  SAMSUNG DV9BTA020AE 9 kg Heat Pump Tumble Drye...     599.99
# 3  LOGIK LCD7W18 7 kg Condenser Tumble Dryer - White     189.00
# 4     LOGIK LVD7W18 7 kg Vented Tumble Dryer - White     189.00
#
#    Customer Rating  Rating Count
# 0             4.25         718.0
# 1             4.15         119.0
# 2             4.75          11.0
# 3             4.60        2337.0
# 4             4.35        3319.0

# %%
# Save cleansed data to new CSV

#tumble_dryers.to_csv('../Clean_Datasets/Currys_Tumble_Dryers.csv', index=False)

# %% [markdown]
# ## Televisions

# %%
# Print TV csv as dataframe

televisions
# Out:
#     LG OLED48C14LB 48" Smart 4K Ultra HD HDR OLED TV with Google Assistant & Amazon Alexa  \
# 0    SAMSUNG QE50QN94AATXXU 50" Smart 4K Ultra HD H...
# 1    SAMSUNG QE65QN95AATXXU 65" Smart 4K Ultra HD H...
# 2    LG OLED42C24LA 42" Smart 4K Ultra HD HDR OLED ...
# 3    SAMSUNG QE55QN700ATXXU 55" Smart 8K HDR Neo QL...
# 4    SAMSUNG The Frame QE43LS03AAUXXU 43" Smart 4K ...
# ..                                                 ...
# 507  SAMSUNG Bevelled 65" Customisable Frame Bezel ...
# 508  LG OLED65A26LA 65" Smart 4K Ultra HD HDR OLED ...
# 509  SAMSUNG Bevelled 55" Customisable Frame Bezel ...
# 510  LG 75QNED916QA 75" Smart 4K Ultra HD HDR QNED ...
# 511  SAMSUNG QE85Q70AATXXU 85" Smart 4K Ultra HD HD...
#
#       869.0   4.7  239.0
# 0     799.0  4.45  172.0
# 1    1499.0  4.45  142.0
# 2    1299.0   NaN    NaN
# 3    1199.0  4.05   12.0
# 4     699.0  4.30  128.0
# ..      ...   ...    ...
# 507    99.0   NaN    NaN
# 508  2199.0   NaN    NaN
# 509    99.0   NaN    NaN
# ...

# %%
# Insert columns titles for dataframe

televisions.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

televisions.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG QE50QN94AATXXU 50" Smart 4K Ultra HD H...      799.0
# 1  SAMSUNG QE65QN95AATXXU 65" Smart 4K Ultra HD H...     1499.0
# 2  LG OLED42C24LA 42" Smart 4K Ultra HD HDR OLED ...     1299.0
# 3  SAMSUNG QE55QN700ATXXU 55" Smart 8K HDR Neo QL...     1199.0
# 4  SAMSUNG The Frame QE43LS03AAUXXU 43" Smart 4K ...      699.0
#
#    Customer Rating  Rating Count
# 0             4.45         172.0
# 1             4.45         142.0
# 2              NaN           NaN
# 3             4.05          12.0
# 4             4.30         128.0

# %%
# View dataframe types 

televisions.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

televisions['Rating Count'] = televisions['Rating Count'].fillna(0)

# %%
# Print dataframe

televisions.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG QE50QN94AATXXU 50" Smart 4K Ultra HD H...      799.0
# 1  SAMSUNG QE65QN95AATXXU 65" Smart 4K Ultra HD H...     1499.0
# 2  LG OLED42C24LA 42" Smart 4K Ultra HD HDR OLED ...     1299.0
# 3  SAMSUNG QE55QN700ATXXU 55" Smart 8K HDR Neo QL...     1199.0
# 4  SAMSUNG The Frame QE43LS03AAUXXU 43" Smart 4K ...      699.0
#
#    Customer Rating  Rating Count
# 0             4.45         172.0
# 1             4.45         142.0
# 2              NaN           0.0
# 3             4.05          12.0
# 4             4.30         128.0

# %%
# Save cleansed data to new CSV

#televisions.to_csv('../Clean_Datasets/Currys_Televisions.csv', index=False)

# %% [markdown]
# ## Vacuum Cleaners

# %%
# Print vacuum cleaners csv as dataframe

vac_cleaners
# Out:
#     DYSON V12 Detect Slim Absolute Cordless Vacuum Cleaner - Yellow & Nickel  \
# 0    SAMSUNG Jet 60 Turbo Max 150 W Suction Power C...
# 1    HOOVER Upright 300 Pets HU300UPT Bagless Vacuu...
# 2    SHARK Anti Hair Wrap Plus Powered Lift-Away & ...
# 3    SHARK Anti Hair Wrap with Pet Tool IZ201UKT Co...
# 4    SHARK Anti Hair Wrap with PowerFins IZ300UKT C...
# ..                                                 ...
# 257  SAMSUNG Bespoke Jet Complete Extra Max 210 W S...
# 258  TOWER T108000BLG Upright Bagless Vacuum Cleane...
# 259  BEKO VCO32801AR Cylinder Bagless Vacuum Cleane...
# 260  TOWER T121001 Upright Bagless Vacuum Cleaner -...
# 261  BELDRAY Airgility Pet Max BEL01004 Cordless Va...
#
#      529.99  Unnamed: 2  Unnamed: 3
# 0    199.00        4.75        32.0
# 1    149.00        4.35       118.0
# 2    199.00        4.60       205.0
# 3    227.53        4.55     10672.0
# 4    279.00        4.45       723.0
# ..      ...         ...         ...
# ...

# %%
# Insert columns titles for dataframe

vac_cleaners.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

vac_cleaners.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Jet 60 Turbo Max 150 W Suction Power C...     199.00
# 1  HOOVER Upright 300 Pets HU300UPT Bagless Vacuu...     149.00
# 2  SHARK Anti Hair Wrap Plus Powered Lift-Away & ...     199.00
# 3  SHARK Anti Hair Wrap with Pet Tool IZ201UKT Co...     227.53
# 4  SHARK Anti Hair Wrap with PowerFins IZ300UKT C...     279.00
#
#    Customer Rating  Rating Count
# 0             4.75          32.0
# 1             4.35         118.0
# 2             4.60         205.0
# 3             4.55       10672.0
# 4             4.45         723.0

# %%
# View dataframe types 

vac_cleaners.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

vac_cleaners['Rating Count'] = vac_cleaners['Rating Count'].fillna(0)

# %%
# Print dataframe

vac_cleaners.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Jet 60 Turbo Max 150 W Suction Power C...     199.00
# 1  HOOVER Upright 300 Pets HU300UPT Bagless Vacuu...     149.00
# 2  SHARK Anti Hair Wrap Plus Powered Lift-Away & ...     199.00
# 3  SHARK Anti Hair Wrap with Pet Tool IZ201UKT Co...     227.53
# 4  SHARK Anti Hair Wrap with PowerFins IZ300UKT C...     279.00
#
#    Customer Rating  Rating Count
# 0             4.75          32.0
# 1             4.35         118.0
# 2             4.60         205.0
# 3             4.55       10672.0
# 4             4.45         723.0

# %%
# Save cleansed data to new CSV

#vac_cleaners.to_csv('../Clean_Datasets/Currys_Vacuum_Cleaners.csv', index=False)

# %% [markdown]
# ## Washer Dryers

# %%
# Print washers dryers csv as dataframe

washer_dryers
# Out:
#     SAMSUNG Series 5 ecobubble WD80TA046BE/EU 8 kg Washer Dryer - White  \
# 0    BOSCH Series 4 WNA134U8GB 8 kg Washer Dryer - ...
# 1    BOSCH Serie | 6 WNA14490GB 9 kg Washer Dryer -...
# 2    AEG Dual Sense L7WEE965R 9 kg Washer Dryer - W...
# 3    SAMSUNG Series 6 AddWash WD10T654DBN/S1 WiFi-e...
# 4    BEKO WDK742421W Bluetooth 7 kg Washer Dryer - ...
# ..                                                 ...
# 132  BOSCH Serie 6 WKD28542GB 7 kg Integrated Washe...
# 133        AEG L7WC8632BI Integrated 8 kg Washer Dryer
# 134  HAIER 636 Series HWD100-BP14636N 10 kg Washer ...
# 135   SHARP ES-NDH0144WC-EN 10 kg Washer Dryer - White
# 136  HOOVER H-Wash 300 H3DS 4965DACGE WiFi-enabled ...
#
#        589.0  4.45  245.0
# 0     699.99  4.60   47.0
# 1     746.00  4.65   82.0
# 2     879.99  4.45  148.0
# 3     809.00  4.15   70.0
# 4     329.99  3.65  305.0
# ..       ...   ...    ...
# 132  1158.00  4.40    6.0
# 133   829.00  4.40  113.0
# 134   649.99  4.55   19.0
# ...

# %%
# Insert columns titles for dataframe

washer_dryers.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

washer_dryers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSCH Series 4 WNA134U8GB 8 kg Washer Dryer - ...     699.99
# 1  BOSCH Serie | 6 WNA14490GB 9 kg Washer Dryer -...     746.00
# 2  AEG Dual Sense L7WEE965R 9 kg Washer Dryer - W...     879.99
# 3  SAMSUNG Series 6 AddWash WD10T654DBN/S1 WiFi-e...     809.00
# 4  BEKO WDK742421W Bluetooth 7 kg Washer Dryer - ...     329.99
#
#    Customer Rating  Rating Count
# 0             4.60          47.0
# 1             4.65          82.0
# 2             4.45         148.0
# 3             4.15          70.0
# 4             3.65         305.0

# %%
# View dataframe types 

washer_dryers.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

washer_dryers['Rating Count'] = washer_dryers['Rating Count'].fillna(0)

# %%
# Print dataframe

washer_dryers.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  BOSCH Series 4 WNA134U8GB 8 kg Washer Dryer - ...     699.99
# 1  BOSCH Serie | 6 WNA14490GB 9 kg Washer Dryer -...     746.00
# 2  AEG Dual Sense L7WEE965R 9 kg Washer Dryer - W...     879.99
# 3  SAMSUNG Series 6 AddWash WD10T654DBN/S1 WiFi-e...     809.00
# 4  BEKO WDK742421W Bluetooth 7 kg Washer Dryer - ...     329.99
#
#    Customer Rating  Rating Count
# 0             4.60          47.0
# 1             4.65          82.0
# 2             4.45         148.0
# 3             4.15          70.0
# 4             3.65         305.0

# %%
# Save cleansed data to new CSV

#washer_dryers.to_csv('../Clean_Datasets/Currys_Washer_Dryers.csv', index=False)

# %% [markdown]
# ## Washing Machines

# %%
# Print washers dryers csv as dataframe

washing_machines
# Out:
#     BOSCH Serie 6 WAU28T64GB 9 kg 1400 Spin Washing Machine - White    479.0  \
# 0    SAMSUNG Series 6 AddWash + Auto Dose WW90T684D...                569.99
# 1    SAMSUNG Series 5+ AddWash WW90T554DAN/S1 WiFi-...                479.00
# 2    AEG Soft Water L9FEC966R 9 kg 1600 Spin Washin...                969.99
# 3    BOSCH Serie 4 WAN28281GB 8 kg 1400 Spin Washin...                439.00
# 4    SAMSUNG Series 5 ecobubble WW90TA046AX/EU 9 kg...                449.00
# ..                                                 ...                   ...
# 268  MONTPELLIER MW8145W 8 kg 1400 Spin Washing Mac...                299.99
# 269  HOOVER H-Wash 500 HWDB 610AMB Auto Dosing WiFi...                509.99
# 270  HOTPOINT Activecare NM11 945 GC UK N 9 kg 1400...                419.00
# 271  BOSCH Serie 8 WAV28EH3GB WiFi-enabled 9 kg 140...               1049.99
# 272  CANDY CBW 48D2XCE Integrated 8 kg 1400 Spin Wa...                449.00
#
#       4.6   541.0
# 0    4.55   180.0
# ...

# %%
# Insert columns titles for dataframe

washing_machines.columns =['Product Name', 'Price (£)', 'Customer Rating', 'Rating Count']

# %%
# Preview dataframe

washing_machines.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Series 6 AddWash + Auto Dose WW90T684D...     569.99
# 1  SAMSUNG Series 5+ AddWash WW90T554DAN/S1 WiFi-...     479.00
# 2  AEG Soft Water L9FEC966R 9 kg 1600 Spin Washin...     969.99
# 3  BOSCH Serie 4 WAN28281GB 8 kg 1400 Spin Washin...     439.00
# 4  SAMSUNG Series 5 ecobubble WW90TA046AX/EU 9 kg...     449.00
#
#    Customer Rating  Rating Count
# 0             4.55         180.0
# 1             4.60         778.0
# 2             4.85         103.0
# 3             4.50        3428.0
# 4             4.65        1304.0

# %%
# View dataframe types 

washing_machines.dtypes
# Out:
# Product Name        object
# Price (£)          float64
# Customer Rating    float64
# Rating Count       float64
# dtype: object

# %%
# Replace NaN values in Rating Count

washing_machines['Rating Count'] = washing_machines['Rating Count'].fillna(0)

# %%
# Print dataframe

washing_machines.head()
# Out:
#                                         Product Name  Price (£)  \
# 0  SAMSUNG Series 6 AddWash + Auto Dose WW90T684D...     569.99
# 1  SAMSUNG Series 5+ AddWash WW90T554DAN/S1 WiFi-...     479.00
# 2  AEG Soft Water L9FEC966R 9 kg 1600 Spin Washin...     969.99
# 3  BOSCH Serie 4 WAN28281GB 8 kg 1400 Spin Washin...     439.00
# 4  SAMSUNG Series 5 ecobubble WW90TA046AX/EU 9 kg...     449.00
#
#    Customer Rating  Rating Count
# 0             4.55         180.0
# 1             4.60         778.0
# 2             4.85         103.0
# 3             4.50        3428.0
# 4             4.65        1304.0

# %%
# Save cleansed data to new CSV

#washing_machines.to_csv('../Clean_Datasets/Currys_Washing_Machines.csv', index=False)
